# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,classification_report
from sklearn.tree import plot_tree

# %%
df = pd.read_csv('PlayTennis.csv')
df
# Out:
#      outlook  temp humidity  windy play
# 0      sunny   hot     high  False   no
# 1      sunny   hot     high   True   no
# 2   overcast   hot     high  False  yes
# 3      rainy  mild     high  False  yes
# 4      rainy  cool   normal  False  yes
# 5      rainy  cool   normal   True   no
# 6   overcast  cool   normal   True  yes
# 7      sunny  mild     high  False   no
# 8      sunny  cool   normal  False  yes
# 9      rainy  mild   normal  False  yes
# 10     sunny  mild   normal   True  yes
# 11  overcast  mild     high   True  yes
# 12  overcast   hot   normal  False  yes
# 13     rainy  mild     high   True   no

# %%
x = df.drop('play',axis=1)
x = pd.get_dummies(x)
y = df['play']
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)
dt = DecisionTreeClassifier(criterion='entropy',random_state=42)
dt.fit(x_train,y_train)
y_pred = dt.predict(x_test)
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# 1.0
#               precision    recall  f1-score   support
#
#           no       1.00      1.00      1.00         1
#          yes       1.00      1.00      1.00         2
#
#     accuracy                           1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3

# %%
plot_tree(dt,feature_names=x.columns,filled=True)
# Out:
# [Text(0.6, 0.9, 'outlook_overcast <= 0.5\nentropy = 0.946\nsamples = 11\nvalue = [4, 7]'),
#  Text(0.5, 0.7, 'humidity_high <= 0.5\nentropy = 1.0\nsamples = 8\nvalue = [4, 4]'),
#  Text(0.55, 0.8, 'True  '),
#  Text(0.2, 0.5, 'windy <= 0.5\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.1, 0.3, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.3, 0.3, 'outlook_rainy <= 0.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.2, 0.1, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4, 0.1, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8, 0.5, 'outlook_sunny <= 0.5\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.7, 0.3, 'windy <= 0.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6, 0.1, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8, 0.1, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9, 0.3, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7, 0.7, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6499999999999999, 0.8, '  False')]

# %%
dt = DecisionTreeClassifier(criterion='entropy',random_state=42,max_depth=2)
dt.fit(x_train,y_train)
y_pred = dt.predict(x_test)
plot_tree(dt,feature_names=x.columns,filled=True)
# Out:
# [Text(0.6, 0.8333333333333334, 'outlook_overcast <= 0.5\nentropy = 0.946\nsamples = 11\nvalue = [4, 7]'),
#  Text(0.4, 0.5, 'humidity_high <= 0.5\nentropy = 1.0\nsamples = 8\nvalue = [4, 4]'),
#  Text(0.5, 0.6666666666666667, 'True  '),
#  Text(0.2, 0.16666666666666666, 'entropy = 0.811\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.6, 0.16666666666666666, 'entropy = 0.811\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.8, 0.5, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.7, 0.6666666666666667, '  False')]

# %%
df = pd.read_csv('diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
x = df.drop('Outcome',axis=1)
y = df['Outcome']
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)
dt = DecisionTreeClassifier(criterion='entropy',random_state=42)
dt.fit(x_train,y_train)
y_pred = dt.predict(x_test)
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# 0.7207792207792207
#               precision    recall  f1-score   support
#
#            0       0.79      0.77      0.78        99
#            1       0.60      0.64      0.62        55
#
#     accuracy                           0.72       154
#    macro avg       0.70      0.70      0.70       154
# weighted avg       0.72      0.72      0.72       154

# %%
plot_tree(dt,feature_names=x.columns,filled=True)
# Out:
# [Text(0.47609544836956524, 0.9705882352941176, 'Glucose <= 127.5\nentropy = 0.931\nsamples = 614\nvalue = [401, 213]'),
#  Text(0.17909307065217392, 0.9117647058823529, 'Age <= 28.5\nentropy = 0.712\nsamples = 390\nvalue = [314, 76]'),
#  Text(0.32759425951086957, 0.9411764705882353, 'True  '),
#  Text(0.06521739130434782, 0.8529411764705882, 'BMI <= 30.95\nentropy = 0.391\nsamples = 221\nvalue = [204, 17]'),
#  Text(0.021739130434782608, 0.7941176470588235, 'DiabetesPedigreeFunction <= 0.672\nentropy = 0.068\nsamples = 124\nvalue = [123, 1]'),
#  Text(0.010869565217391304, 0.7352941176470589, 'entropy = 0.0\nsamples = 108\nvalue = [108, 0]'),
#  Text(0.03260869565217391, 0.7352941176470589, 'DiabetesPedigreeFunction <= 0.686\nentropy = 0.337\nsamples = 16\nvalue = [15, 1]'),
#  Text(0.021739130434782608, 0.6764705882352942, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.043478260869565216, 0.6764705882352942, 'entropy = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(0.10869565217391304, 0.7941176470588235, 'BloodPressure <= 37.0\nentropy = 0.646\nsamples = 97\nvalue = [81, 16]'),
#  Text(0.09782608695652174, 0.7352941176470589, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.11956521739130435, 0.7352941176470589, 'DiabetesPedigreeFunction <= 0.501\nentropy = 0.603\nsamples = 95\nvalue = [81.0, 14.0]'),
#  Text(0.06521739130434782, 0.6764705882352942, 'SkinThickness <= 8.5\nentropy = 0.409\nsamples = 61\nvalue = [56, 5]'),
#  Text(0.03260869565217391, 0.6176470588235294, 'Glucose <= 109.5\nentropy = 0.985\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.021739130434782608, 0.5588235294117647, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.043478260869565216, 0.5588235294117647, 'Glucose <= 123.0\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.03260869565217391, 0.5, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.05434782608695652, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.09782608695652174, 0.6176470588235294, 'BMI <= 31.8\nentropy = 0.229\nsamples = 54\nvalue = [52, 2]'),
#  Text(0.08695652173913043, 0.5588235294117647, 'Pregnancies <= 2.5\nentropy = 1.0\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.07608695652173914, 0.5, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.09782608695652174, 0.5, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.10869565217391304, 0.5588235294117647, 'entropy = 0.0\nsamples = 50\nvalue = [50, 0]'),
#  Text(0.17391304347826086, 0.6764705882352942, 'DiabetesPedigreeFunction <= 0.544\nentropy = 0.834\nsamples = 34\nvalue = [25, 9]'),
#  Text(0.14130434782608695, 0.6176470588235294, 'DiabetesPedigreeFunction <= 0.512\nentropy = 0.918\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.13043478260869565, 0.5588235294117647, 'SkinThickness <= 41.5\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.11956521739130435, 0.5, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.14130434782608695, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.15217391304347827, 0.5588235294117647, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.20652173913043478, 0.6176470588235294, 'BloodPressure <= 67.0\nentropy = 0.677\nsamples = 28\nvalue = [23, 5]'),
#  Text(0.17391304347826086, 0.5588235294117647, 'Insulin <= 70.0\nentropy = 0.971\nsamples = 10\nvalue = [6, 4]'),
#  Text(0.16304347826086957, 0.5, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.18478260869565216, 0.5, 'SkinThickness <= 34.0\nentropy = 0.918\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.17391304347826086, 0.4411764705882353, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.1956521739130435, 0.4411764705882353, 'DiabetesPedigreeFunction <= 0.86\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.18478260869565216, 0.38235294117647056, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.20652173913043478, 0.38235294117647056, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2391304347826087, 0.5588235294117647, 'Age <= 21.5\nentropy = 0.31\nsamples = 18\nvalue = [17, 1]'),
#  Text(0.22826086956521738, 0.5, 'BMI <= 42.8\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.21739130434782608, 0.4411764705882353, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.2391304347826087, 0.4411764705882353, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.25, 0.5, 'entropy = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(0.29296875, 0.8529411764705882, 'BMI <= 26.35\nentropy = 0.933\nsamples = 169\nvalue = [110, 59]'),
#  Text(0.21739130434782608, 0.7941176470588235, 'BMI <= 9.65\nentropy = 0.191\nsamples = 34\nvalue = [33, 1]'),
#  Text(0.20652173913043478, 0.7352941176470589, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.22826086956521738, 0.7352941176470589, 'entropy = 0.0\nsamples = 33\nvalue = [33, 0]'),
#  Text(0.3685461956521739, 0.7941176470588235, 'Glucose <= 94.5\nentropy = 0.986\nsamples = 135\nvalue = [77, 58]'),
#  Text(0.25, 0.7352941176470589, 'Glucose <= 28.5\nentropy = 0.555\nsamples = 31\nvalue = [27, 4]'),
#  Text(0.2391304347826087, 0.6764705882352942, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.2608695652173913, 0.6764705882352942, 'Pregnancies <= 9.5\nentropy = 0.362\nsamples = 29\nvalue = [27, 2]'),
#  Text(0.25, 0.6176470588235294, 'entropy = 0.0\nsamples = 22\nvalue = [22, 0]'),
#  Text(0.2717391304347826, 0.6176470588235294, 'SkinThickness <= 27.0\nentropy = 0.863\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.2608695652173913, 0.5588235294117647, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.2826086956521739, 0.5588235294117647, 'Insulin <= 27.0\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.2717391304347826, 0.5, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.29347826086956524, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.48709239130434784, 0.7352941176470589, 'DiabetesPedigreeFunction <= 0.521\nentropy = 0.999\nsamples = 104\nvalue = [50.0, 54.0]'),
#  Text(0.41983695652173914, 0.6764705882352942, 'SkinThickness <= 27.5\nentropy = 0.984\nsamples = 73\nvalue = [42, 31]'),
#  Text(0.37228260869565216, 0.6176470588235294, 'BloodPressure <= 83.0\nentropy = 0.991\nsamples = 45\nvalue = [20, 25]'),
#  Text(0.3423913043478261, 0.5588235294117647, 'DiabetesPedigreeFunction <= 0.387\nentropy = 0.874\nsamples = 34\nvalue = [10, 24]'),
#  Text(0.31521739130434784, 0.5, 'Pregnancies <= 7.5\nentropy = 0.75\nsamples = 28\nvalue = [6, 22]'),
#  Text(0.29347826086956524, 0.4411764705882353, 'BloodPressure <= 61.0\nentropy = 0.439\nsamples = 22\nvalue = [2, 20]'),
#  Text(0.2826086956521739, 0.38235294117647056, 'DiabetesPedigreeFunction <= 0.238\nentropy = 1.0\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.2717391304347826, 0.3235294117647059, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.29347826086956524, 0.3235294117647059, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.30434782608695654, 0.38235294117647056, 'entropy = 0.0\nsamples = 18\nvalue = [0, 18]'),
#  Text(0.33695652173913043, 0.4411764705882353, 'Glucose <= 123.5\nentropy = 0.918\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.32608695652173914, 0.38235294117647056, 'DiabetesPedigreeFunction <= 0.265\nentropy = 0.722\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.31521739130434784, 0.3235294117647059, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.33695652173913043, 0.3235294117647059, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.34782608695652173, 0.38235294117647056, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3695652173913043, 0.5, 'Pregnancies <= 6.5\nentropy = 0.918\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.358695652173913, 0.4411764705882353, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.3804347826086957, 0.4411764705882353, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.40217391304347827, 0.5588235294117647, 'SkinThickness <= 18.0\nentropy = 0.439\nsamples = 11\nvalue = [10, 1]'),
#  Text(0.391304347826087, 0.5, 'entropy = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.41304347826086957, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4673913043478261, 0.6176470588235294, 'BloodPressure <= 89.0\nentropy = 0.75\nsamples = 28\nvalue = [22, 6]'),
#  Text(0.45652173913043476, 0.5588235294117647, 'BloodPressure <= 67.0\nentropy = 0.619\nsamples = 26\nvalue = [22, 4]'),
#  Text(0.43478260869565216, 0.5, 'BloodPressure <= 57.0\nentropy = 1.0\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.42391304347826086, 0.4411764705882353, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.44565217391304346, 0.4411764705882353, 'DiabetesPedigreeFunction <= 0.394\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.43478260869565216, 0.38235294117647056, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.45652173913043476, 0.38235294117647056, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4782608695652174, 0.5, 'Insulin <= 155.0\nentropy = 0.286\nsamples = 20\nvalue = [19, 1]'),
#  Text(0.4673913043478261, 0.4411764705882353, 'entropy = 0.0\nsamples = 18\nvalue = [18, 0]'),
#  Text(0.4891304347826087, 0.4411764705882353, 'DiabetesPedigreeFunction <= 0.271\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.4782608695652174, 0.38235294117647056, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5, 0.38235294117647056, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4782608695652174, 0.5588235294117647, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.5543478260869565, 0.6764705882352942, 'Pregnancies <= 6.5\nentropy = 0.824\nsamples = 31\nvalue = [8, 23]'),
#  Text(0.5434782608695652, 0.6176470588235294, 'SkinThickness <= 47.5\nentropy = 0.982\nsamples = 19\nvalue = [8, 11]'),
#  Text(0.532608695652174, 0.5588235294117647, 'Age <= 34.5\nentropy = 0.937\nsamples = 17\nvalue = [6, 11]'),
#  Text(0.5217391304347826, 0.5, 'Insulin <= 48.0\nentropy = 1.0\nsamples = 12\nvalue = [6, 6]'),
#  Text(0.5108695652173914, 0.4411764705882353, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.532608695652174, 0.4411764705882353, 'Age <= 33.5\nentropy = 0.811\nsamples = 8\nvalue = [2, 6]'),
#  Text(0.5217391304347826, 0.38235294117647056, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.5434782608695652, 0.38235294117647056, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.5434782608695652, 0.5, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.5543478260869565, 0.5588235294117647, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.5652173913043478, 0.6176470588235294, 'entropy = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(0.7730978260869565, 0.9117647058823529, 'BMI <= 29.95\nentropy = 0.964\nsamples = 224\nvalue = [87, 137]'),
#  Text(0.6245966372282609, 0.9411764705882353, '  False'),
#  Text(0.654891304347826, 0.8529411764705882, 'Glucose <= 145.5\nentropy = 0.895\nsamples = 61\nvalue = [42, 19]'),
#  Text(0.5978260869565217, 0.7941176470588235, 'Pregnancies <= 2.5\nentropy = 0.533\nsamples = 33\nvalue = [29, 4]'),
#  Text(0.5869565217391305, 0.7352941176470589, 'entropy = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.6086956521739131, 0.7352941176470589, 'Pregnancies <= 4.5\nentropy = 0.722\nsamples = 20\nvalue = [16, 4]'),
#  Text(0.5978260869565217, 0.6764705882352942, 'Insulin <= 127.5\nentropy = 0.971\nsamples = 10\nvalue = [6, 4]'),
#  Text(0.5869565217391305, 0.6176470588235294, 'BMI <= 23.45\nentropy = 1.0\nsamples = 8\nvalue = [4, 4]'),
#  Text(0.5760869565217391, 0.5588235294117647, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.5978260869565217, 0.5588235294117647, 'Age <= 37.0\nentropy = 0.918\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.5869565217391305, 0.5, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6086956521739131, 0.5, 'BMI <= 25.7\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.5978260869565217, 0.4411764705882353, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6195652173913043, 0.4411764705882353, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6086956521739131, 0.6176470588235294, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6195652173913043, 0.6764705882352942, 'entropy = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.7119565217391305, 0.7941176470588235, 'Age <= 62.0\nentropy = 0.996\nsamples = 28\nvalue = [13, 15]'),
#  Text(0.7010869565217391, 0.7352941176470589, 'Age <= 41.0\nentropy = 0.971\nsamples = 25\nvalue = [10, 15]'),
#  Text(0.6739130434782609, 0.6764705882352942, 'Glucose <= 163.0\nentropy = 0.971\nsamples = 15\nvalue = [9, 6]'),
#  Text(0.6521739130434783, 0.6176470588235294, 'Pregnancies <= 2.5\nentropy = 0.722\nsamples = 10\nvalue = [8, 2]'),
#  Text(0.6413043478260869, 0.5588235294117647, 'Pregnancies <= 1.5\nentropy = 1.0\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.6304347826086957, 0.5, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6521739130434783, 0.5, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6630434782608695, 0.5588235294117647, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.6956521739130435, 0.6176470588235294, 'BloodPressure <= 60.0\nentropy = 0.722\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.6847826086956522, 0.5588235294117647, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7065217391304348, 0.5588235294117647, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.7282608695652174, 0.6764705882352942, 'Age <= 53.5\nentropy = 0.469\nsamples = 10\nvalue = [1, 9]'),
#  Text(0.717391304347826, 0.6176470588235294, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.7391304347826086, 0.6176470588235294, 'Pregnancies <= 8.5\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.7282608695652174, 0.5588235294117647, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.75, 0.5588235294117647, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7228260869565217, 0.7352941176470589, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.8913043478260869, 0.8529411764705882, 'Glucose <= 165.5\nentropy = 0.85\nsamples = 163\nvalue = [45, 118]'),
#  Text(0.8260869565217391, 0.7941176470588235, 'BloodPressure <= 91.0\nentropy = 0.951\nsamples = 108\nvalue = [40, 68]'),
#  Text(0.8152173913043478, 0.7352941176470589, 'BloodPressure <= 61.0\nentropy = 0.973\nsamples = 99\nvalue = [40.0, 59.0]'),
#  Text(0.7717391304347826, 0.6764705882352942, 'Age <= 40.0\nentropy = 0.391\nsamples = 13\nvalue = [1, 12]'),
#  Text(0.7608695652173914, 0.6176470588235294, 'entropy = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(0.782608695652174, 0.6176470588235294, 'Age <= 42.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.7717391304347826, 0.5588235294117647, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7934782608695652, 0.5588235294117647, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8586956521739131, 0.6764705882352942, 'Age <= 30.5\nentropy = 0.994\nsamples = 86\nvalue = [39, 47]'),
#  Text(0.8260869565217391, 0.6176470588235294, 'Insulin <= 252.5\nentropy = 0.927\nsamples = 38\nvalue = [25, 13]'),
#  Text(0.8152173913043478, 0.5588235294117647, 'Glucose <= 156.0\nentropy = 0.999\nsamples = 27\nvalue = [14, 13]'),
#  Text(0.8043478260869565, 0.5, 'BloodPressure <= 85.0\nentropy = 0.98\nsamples = 24\nvalue = [14, 10]'),
#  Text(0.7934782608695652, 0.4411764705882353, 'BloodPressure <= 73.0\nentropy = 0.946\nsamples = 22\nvalue = [14, 8]'),
#  Text(0.7717391304347826, 0.38235294117647056, 'Insulin <= 173.0\nentropy = 0.996\nsamples = 13\nvalue = [6, 7]'),
#  Text(0.7608695652173914, 0.3235294117647059, 'DiabetesPedigreeFunction <= 0.183\nentropy = 0.971\nsamples = 10\nvalue = [6, 4]'),
#  Text(0.75, 0.2647058823529412, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7717391304347826, 0.2647058823529412, 'BloodPressure <= 65.0\nentropy = 1.0\nsamples = 8\nvalue = [4, 4]'),
#  Text(0.7608695652173914, 0.20588235294117646, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.782608695652174, 0.20588235294117646, 'DiabetesPedigreeFunction <= 0.318\nentropy = 0.918\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.7717391304347826, 0.14705882352941177, 'Pregnancies <= 1.5\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.7608695652173914, 0.08823529411764706, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.782608695652174, 0.08823529411764706, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7934782608695652, 0.14705882352941177, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.782608695652174, 0.3235294117647059, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.8152173913043478, 0.38235294117647056, 'Pregnancies <= 4.5\nentropy = 0.503\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.8043478260869565, 0.3235294117647059, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.8260869565217391, 0.3235294117647059, 'Glucose <= 146.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.8152173913043478, 0.2647058823529412, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8369565217391305, 0.2647058823529412, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8152173913043478, 0.4411764705882353, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8260869565217391, 0.5, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.8369565217391305, 0.5588235294117647, 'entropy = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.8913043478260869, 0.6176470588235294, 'Age <= 33.5\nentropy = 0.871\nsamples = 48\nvalue = [14, 34]'),
#  Text(0.8804347826086957, 0.5588235294117647, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.9021739130434783, 0.5588235294117647, 'SkinThickness <= 45.0\nentropy = 0.91\nsamples = 43\nvalue = [14.0, 29.0]'),
#  Text(0.8913043478260869, 0.5, 'BloodPressure <= 75.0\nentropy = 0.942\nsamples = 39\nvalue = [14.0, 25.0]'),
#  Text(0.8695652173913043, 0.4411764705882353, 'Pregnancies <= 7.0\nentropy = 0.65\nsamples = 12\nvalue = [2, 10]'),
#  Text(0.8586956521739131, 0.38235294117647056, 'SkinThickness <= 28.5\nentropy = 1.0\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.8478260869565217, 0.3235294117647059, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8695652173913043, 0.3235294117647059, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8804347826086957, 0.38235294117647056, 'entropy = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.9130434782608695, 0.4411764705882353, 'Pregnancies <= 10.0\nentropy = 0.991\nsamples = 27\nvalue = [12, 15]'),
#  Text(0.9021739130434783, 0.38235294117647056, 'Glucose <= 155.5\nentropy = 0.954\nsamples = 24\nvalue = [9, 15]'),
#  Text(0.8913043478260869, 0.3235294117647059, 'Glucose <= 152.5\nentropy = 0.993\nsamples = 20\nvalue = [9, 11]'),
#  Text(0.8804347826086957, 0.2647058823529412, 'SkinThickness <= 16.5\nentropy = 0.964\nsamples = 18\nvalue = [7, 11]'),
#  Text(0.8586956521739131, 0.20588235294117646, 'Age <= 44.5\nentropy = 0.918\nsamples = 9\nvalue = [6, 3]'),
#  Text(0.8478260869565217, 0.14705882352941177, 'BMI <= 39.8\nentropy = 1.0\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.8369565217391305, 0.08823529411764706, 'BMI <= 33.4\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.8260869565217391, 0.029411764705882353, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8478260869565217, 0.029411764705882353, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.8586956521739131, 0.08823529411764706, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8695652173913043, 0.14705882352941177, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.9021739130434783, 0.20588235294117646, 'SkinThickness <= 40.0\nentropy = 0.503\nsamples = 9\nvalue = [1, 8]'),
#  Text(0.8913043478260869, 0.14705882352941177, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.9130434782608695, 0.14705882352941177, 'BloodPressure <= 87.0\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.9021739130434783, 0.08823529411764706, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9239130434782609, 0.08823529411764706, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9021739130434783, 0.2647058823529412, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9130434782608695, 0.3235294117647059, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.9239130434782609, 0.38235294117647056, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.9130434782608695, 0.5, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.8369565217391305, 0.7352941176470589, 'entropy = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.9565217391304348, 0.7941176470588235, 'Glucose <= 178.5\nentropy = 0.439\nsamples = 55\nvalue = [5, 50]'),
#  Text(0.9456521739130435, 0.7352941176470589, 'entropy = 0.0\nsamples = 18\nvalue = [0, 18]'),
#  Text(0.967391304347826, 0.7352941176470589, 'Pregnancies <= 2.5\nentropy = 0.571\nsamples = 37\nvalue = [5, 32]'),
#  Text(0.9565217391304348, 0.6764705882352942, 'entropy = 0.0\nsamples = 15\nvalue = [0, 15]'),
#  Text(0.9782608695652174, 0.6764705882352942, 'DiabetesPedigreeFunction <= 1.337\nentropy = 0.773\nsamples = 22\nvalue = [5, 17]'),
#  Text(0.967391304347826, 0.6176470588235294, 'DiabetesPedigreeFunction <= 0.314\nentropy = 0.61\nsamples = 20\nvalue = [3, 17]'),
#  Text(0.9565217391304348, 0.5588235294117647, 'BMI <= 35.3\nentropy = 0.985\nsamples = 7\nvalue = [3, 4]'),
#  Text(0.9456521739130435, 0.5, 'Glucose <= 192.0\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.9347826086956522, 0.4411764705882353, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.9565217391304348, 0.4411764705882353, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.967391304347826, 0.5, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.9782608695652174, 0.5588235294117647, 'entropy = 0.0\nsamples = 13\nvalue = [0, 13]'),
#  Text(0.9891304347826086, 0.6176470588235294, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]')]
